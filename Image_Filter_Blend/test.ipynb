# %%
from myfunc import project1
import cv2

proj = project1()
# Out:
# 计算机视觉 Project 1: Image Filtering and Hybrid Images

# %%
img1 = cv2.imread('dog.png')
img2 = cv2.imread('cat.png')

# %%
proj.mean_filter(img1, 3)

# %%
proj.gaussian_filter(img1, 3)
